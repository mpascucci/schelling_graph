# %% [markdown]
# # Schelling graph simulation

# %%
# Jupyter notebook cell
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from graph_definition import g
import numpy as np

n = len(g.nodes)
chips = np.random.randint(0, 60, size=n)
g.init_chips_with_sample(chips)
g.plot();

# %%
#g.run_rounds(500)
g.run_rounds(stop_when=g.is_segregated, max_rounds=5000)
logs = g.plot();

# %%
from schelling_graph.visualization import draw_matrix_3D
draw_matrix_3D(g.matrix)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes3D: xlabel='X', ylabel='Y', zlabel='Chips'>)

# %%
np.indices((2,3)).reshape(2,6).T
# Out:
# array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2]])
